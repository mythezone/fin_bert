# %%
from data.process.token_encoder import FinancialTokenEncoder
from data.process.bucketizer import ExponentialBucketizer, UniformBucketizer
import numpy as np 
import pandas as pd

open_pct = np.random.rand(100)*0.2-0.1
high_pct = np.random.rand(100) * 0.2 - 0.1
low_pct = np.random.rand(100) * 0.2 - 0.1
close_pct = np.random.rand(100) * 0.2 - 0.1

# df = pd.DataFrame({
#     'open_pct': open_pct,
#     'high_pct': high_pct,
#     'low_pct': low_pct,
#     'close_pct': close_pct
# })
df = pd.read_pickle('dataset/pickled/daily_percentage_df.pkl')

# %%
k = 20
eb = ExponentialBucketizer(k)
ub = UniformBucketizer(k)

# %%
fte_eb = FinancialTokenEncoder()

fte_eb.set_bucketizer(eb)

# %%
fte_eb.plot_zero_e_grid(df)

# %%
eb2 = ExponentialBucketizer(k, 1.11, 1e-5)
fte_eb2 = FinancialTokenEncoder(eb2)
fte_eb2.plot_bucket_distribution(df)

# %%
fte_ub = FinancialTokenEncoder(ub)
# ub_fte_res = fte_ub.encode_df(df)
# ub_fte_res.to_pickle('dataset/pickled/ub_fte_res.pkl')
fte_ub.plot_bucket_distribution(df)

# %%
df_raw = pd.read_pickle("dataset/pickled/daily_df.pkl")
df_raw.head(10)
# Out:
#    id        Date   Open   High    Low  Close     Volume   Ret_adj  \
# 0   1  2015-01-05  15.99  16.28  15.60  16.02  286043643  0.011364
# 1   1  2015-01-06  15.85  16.39  15.55  15.78  216642140 -0.014981
# 2   1  2015-01-07  15.56  15.83  15.30  15.48  170012067 -0.019011
# 3   1  2015-01-08  15.50  15.57  14.90  14.96  140771421 -0.033592
# 4   1  2015-01-09  14.90  15.87  14.71  15.08  250850023  0.008021
# 5   1  2015-01-12  14.87  15.05  14.50  14.77  155329086 -0.020557
# 6   1  2015-01-13  14.65  14.90  14.61  14.68   81687477 -0.006093
# 7   1  2015-01-14  14.78  15.20  14.70  14.81  126302964  0.008856
# 8   1  2015-01-15  14.85  15.35  14.71  15.35  124217032  0.036462
# 9   1  2015-01-16  15.40  15.62  15.18  15.37  155584633  0.001303
#
#      Close_adj
# 0  1094.533933
# 1  1078.136421
# 2  1057.639531
# 3  1022.111588
# 4  1030.310344
# 5  1009.130224
# 6  1002.981157
# 7  1011.863143
# 8  1048.757545
# 9  1050.124004

# %%
res = hp.transform(df_raw)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/hf/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1824, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1823 try:
# -> 1824     result = self._python_apply_general(f, self._selected_obj)
#    1825     if (
#    1826         not isinstance(self.obj, Series)
#    1827         and self._selection is None
#    1828         and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1829     ):
#
# File ~/miniconda3/envs/hf/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1859 """
#    1860 Apply function f in python space
#    1861
#    (...)   1883     data after applying f
#    1884 """
# ...
